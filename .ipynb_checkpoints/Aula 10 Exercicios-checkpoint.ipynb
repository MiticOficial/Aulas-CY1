# %%
#Boa noite alunos! Hoje nós iremos fazer alguns exercicios baseados em cada aula que vimos até agora!
#Cada sessão terá 3 exercicios, sendo eles facil, médio e dificil, respectivamente.
#Cada exercicio terá a explicação logica de como realiza-lo, mas você deverá pensar em como resolver o problema usando a linguagem!

#Como é um exercicio?

'''
Para exemplificar como serão os exercicios, aqui está um exemplo:


1) Faça um programa que lê o seu nome (utilizando o input) e depois exibe ele na tela.

Entrada: 

Mateus

Saída:

Boa tarde, Mateus!

Itens utilizados nesse exercicio: Variaveis, input, strings(textos entre aspas "") e print.


A "entrada" seria o dado que você daria para o seu programa por meio do input ou variaveis ou listas ou enfim...
e a "saida" seria oque iria aparecer no console no final.
*ATENÇÃO, NEM TODOS OS EXERCICIOS IRÃO USAR O INPUT! Eu apenas dei um exemplo utilizando ele.
'''


#Resolução:

nome = input("Escreva seu nome: ")
print("Boa tarde, "+ nome)
# Out:
# Escreva seu nome:  Mateus
# Boa tarde, Mateus

# %%
#Então vamos lá!

#Exercicios Aula 01 - 

#Nivel facil:
'''
Crie uma variavel com qualquer valor (Int,Float,String ou Boolean) e exiba ela na tela.

Entrada:

Variavel 

Saida:

valor da variavel

Itens utilizados nesse exercicio: Variaveis, Print e dados (string, int, float ou boolean)
'''

#Responda nessa celula, aqui abaixo:

# %%
#Exercicios Aula 01 - 

#Nivel Médio:

'''
Crie duas variaveis e faça um calculo utilizando qualquer uma das expressões matematicas
para chegar no valor de 1914. 

Entrada:

Variavel com numero 1
Variavel com numero 2

Saída:

O valor desse calculo é 1914
'''

#Responda nessa celula, aqui abaixo:

# %%
#Então vamos lá, vamos para os exercicios da segunda aula!
#Exercicios Aula 02 - 

#Nivel facil:

'''
Crie um programa que, dada uma string com uma frase informada pelo usuário (incluindo espaços em branco), conte:

quantos espaços em branco existem na frase.

Entrada:

Variavel com string

Saída:

Essa String tem um total de X espaços em branco



Itens utilizados: Variaveis, Strings, .find(), print(). Caso não lembre como utilizar algum desses
você pode rever na apostila (Aula 02 - Strings)
'''

#Responda nessa celula, aqui abaixo:

# %%
#Então vamos lá, vamos para os exercicios da segunda aula!
#Exercicios Aula 02 - 

#Nivel Médio:

'''
Crie um programa que, dada uma string com uma frase informada pelo usuário (incluindo espaços em branco), conte:

quantas vezes aparecem as vogais a, e, i, o, u.

Entrada:

Variavel com string

Saída:

Essa String tem um total de X vogais


Itens utilizados: Variaveis, Strings, .count(), print(). 
Caso não lembre como utilizar algum desses, você pode rever na apostila (Aula 02 - Strings)
'''

#Responda nessa celula, aqui abaixo:
# Out:
# 3

# %%
#Então vamos lá, vamos para os exercicios da segunda aula!
#Exercicios Aula 02 - 

#Nivel Dificil:

'''
Faça um programa que recebe o nome completo do usuário e imprime:

- Só o primeiro nome;
- Sobrenome completo;
- Apenas o último nome.

Entrada:

Mateus André Silva Santos

Saída:

Mateus
André Silva Santos
Santos

Itens utilizados: Variaveis, Strings, input(), indices e print()
Caso não lembre como utilizar algum desses, você pode rever na apostila (Aula 02 - Strings)
'''

#Responda nessa celula, aqui abaixo:

# %%
#Então vamos lá, vamos para os exercicios da segunda aula!
#Exercicios Aula 02 - 

#Nivel Extra-Hardcore 🤘(Valendo gemas no portal):

'''
Crie uma variavel que recebe um valor numerico e exiba ela junto com um texto.

Entrada:

5

Saída: 

Joãozinho tem 5 irmãos!

Itens utilizados: Variaveis, Str(), input() e print().
'''

#Responda nessa celula, aqui abaixo:

# %%
#Então vamos lá, vamos para os exercicios da Terceira aula, você está indo bem!
#Exercicios Aula 03 - 

#Nivel facil:

'''
Crie uma lista chamada Oscar e dentro dessa lista coloque os ultimos 5 ganhadores 
das categorias de:
- melhor animação,
- melhor filme,
- melhor direção,
- melhor trilha sonora
- melhor ator.

*Pesquise na internet para descobrir*

Após isso, exiba cada vencedor da lista com a sua respectiva categoria.

Entrada:

Lista com os filmes e atores

Saída:

A melhor animação foi: filme 1
O melhor filme foi: Filme 2
A melhor direção foi: Filme 3
A melhor trilha sonora foi: Filme 4
O melhor ator foi: Ator


Itens utilizados: Listas e print().
'''

#Responda nessa celula, aqui abaixo:

# %%
#Então vamos lá, vamos para os exercicios da Terceira aula, você está indo bem!
#Exercicios Aula 03 - 

#Nivel Médio:

'''
Crie uma lista vazia chamada convidados e adicione 10 convidados nessa lista utilizando os metodos .Append() e/ou .insert().

Após isso remova alguns convidados e armazene eles em uma nova lista chamada "Excluidos". Depois exiba 
o numero total de convidados da sua festa e o numero total de pessoas excluidas.

Entrada: 

Lista criada

Saída:

Minha festa está com: X convidados.
Minha festa teve: X pessoas ausentes.

Itens utilizados: Listas, .append(), .insert(), .pop() e print().
'''

#Responda nessa celula, aqui abaixo:

# %%
#Então vamos lá, vamos para os exercicios da Terceira aula, você está indo bem!
#Exercicios Aula 03 - 

#Nivel Dificil:

'''
Imagine que você trabalha em um mercado e está fazendo a contagem de quantos itens iguais aparecem em uma prateleira
Crie uma lista chamada prateleira, que vai receber 10 itens, incluindo alguns repetidos, 
conte quantas vezes esses itens apareceram na lista e exiba na tela com um texto.

Entrada: 

Lista

Sáida:

Na prateleira ainda tem X item

Itens utilizados: Listas, .count() e print().
'''

#Responda nessa celula, aqui abaixo:

# %%
#Então vamos lá, vamos para os exercicios da Terceira aula!
#Exercicios Aula 03 - 

#Nivel Extra-Hardcore 🤘(Valendo gemas no portal):

'''
Agora utilizando a ultima lista (prateleira), organize ela em ordem alfabetica, mostre na tela e depois
vamos verificar se é necessario ou não repor a prateleira com mais itens!
SE a o item escolhido tiver aparecido < que 3 vezes na prateleira, mostre na tela "Repor esse item"
SENAO, mostre na tela "Itens suficientes na prateleira"

Entrada: 

Lista

Saida:

Se for menor que 3: 

"Repor esse item"

Se não for menor que 3: 

"Itens suficientes na prateleira"

Itens utilizados: Listas, .count(), if e else, sort() e print().
'''

#Responda nessa celula, aqui abaixo:
# Out:
# Itens suficientes na prateleira

# %%
#Então vamos lá, vamos para os exercicios da Quarta aula!
#Exercicios Aula 04 - 

#Nivel facil:

'''
Crie quatro variaveis, compare as quatro utilizando o AND ou o OR e retorne o valor True.

Entrada:

Variavel1
Variavel2
Variavel3
Variavel4

Saída:

True

Itens utilizados: Variaveis e Operadores de comparação em cadeia.
'''

#Responda nessa celula, aqui abaixo:

# %%
#Então vamos lá, vamos para os exercicios da Quarta aula!
#Exercicios Aula 04 - 

#Nivel Médio:

'''
Imagine que você é um CEO de uma empresa que quer aumentar o salário de seus funcionarios.
Só que para isso, os funcionarios devem ter gerado >= que R$ 20000 para a empresa.

SE os funcionarios conseguiram bater essa meta de gerar >= R$ 20000 para a empresa,
O salario deles que antes era de 2000 reais vai ser ajustado para 2800 Reais.

SENAO SE os funcionarios conseguirem bater uma meta menor, gerar >= 10000 para a empresa,
O salario deles que antes era de 2000 reais vai ser ajustado para 2300 Reais

SENAO o salario deles vai continuar como está.

*O VALOR AJUSTADO DEVE SER ADICIONADO A VARIAVEL SALARIO.*

Entrada:

Salario
renda_gerada

Saída:

Se eles bateram a meta:

"Seu salario foi ajustado para X Reais."

Se eles não bateram a meta:

"Seu salario não sofreu alteração."

Itens utilizados: Variaveis, Operadores de comparação, if, elif e else e print().
'''

#Responda nessa celula, aqui abaixo:

# %%
#Então vamos lá, vamos para os exercicios da Quarta aula!
#Exercicios Aula 04 - 

#Nivel Dificil:

'''
Leia um valor inteiro entre 1 e 12, inclusive. Correspondente a este valor, deve ser apresentado como resposta o mês do ano por extenso, em inglês, com a primeira letra maiúscula.

Entrada
A entrada contém um único valor inteiro.

Saída
Imprima por extenso o nome do mês correspondente ao número existente na entrada, com a primeira letra em maiúscula.

Sem dicas dessa vez :)
'''

#Responda nessa celula, aqui abaixo:

# %%
#VOCÊ CHEGOU AO FIM DA LISTA DE EXERCICIOS! PARABÉNS, EU ESTOU MUITO ORGULHOSO DE VOCÊ! :)))))))
"Agora copie o link abaixo e cole no seu navegador para ver a sua surpresa!!!!"

https://www.youtube.com/watch?v=dQw4w9WgXcQ&ab_channel=RickAstley

#Até o ano que vem! Espero que vocês tenham gostado!
